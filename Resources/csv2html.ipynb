# %%
import pandas as pd
df= pd.read_csv('cities.csv')
df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 0          0          kapaa  22.0752 -159.3190     26.99        77
# 1          1         barrow  71.2906 -156.7887     -5.99        86
# 2          2      busselton -33.6500  115.3333     13.33        68
# 3          3  mar del plata -38.0023  -57.5575     16.08        59
# 4          4          vaini -21.2000 -175.2000     23.09        88
# ..       ...            ...      ...       ...       ...       ...
# 546      546    poshekhonye  58.4993   39.1353      2.33        90
# 547      547  santa rosalia  27.3167 -112.2833     26.61        33
# 548      548      boqueirao  -7.5000  -36.1333     26.75        73
# 549      549      panyutyne  48.9333   36.2833     10.82        56
# 550      550         quibor   9.9287  -69.6201     30.84        39
#
#      Cloudiness  Wind Speed Country        Date
# 0            40        6.17      US  1651608887
# 1           100        5.14      US  1651608707
# ...

# %%
df.to_html('table.html',classes='table table-stripped',index=False)
